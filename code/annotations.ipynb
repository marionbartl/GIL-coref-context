# %% [markdown]
# # Combining Annotations and Majority Voting

# %% [markdown]
# ## Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter

# %%
# print current working directory
print(os.getcwd())

# set working directory if necessary
#os.chdir('/your/path/here/')

# %%
results_dir = '../results/EN/'
annotations_dir = '../results/annotations/'

# need the actual file to get ante_gender
original_file = 'next_token_results_EN_cohtemplates_hifr_PL_qwen32B-4bit.csv'

# %%
#   read in the original file
og_df = pd.read_csv(os.path.join(results_dir,original_file))
og_df.index = np.arange(1, len(og_df) + 1)
og_df.index.name = 'item_no'

# %%
og_df
# Out:
#                                            phrase1  \
# item_no
# 1        The grandparents were waiting on a bench.
# 2        The grandmothers were waiting on a bench.
# 3        The grandfathers were waiting on a bench.
# 4            The monarchs were waiting on a bench.
# 5              The queens were waiting on a bench.
# ...                                            ...
# 626      The daughters were getting off the plane.
# 627           The sons were getting off the plane.
# 628        The spouses were getting off the plane.
# 629          The wives were getting off the plane.
# 630       The husbands were getting off the plane.
#
#                                        phrase2_cut     ante_noun ante_gender  \
# item_no
# 1        Because of the cloudy weather, one of the  grandparents           n
# 2        Because of the cloudy weather, one of the  grandmothers           f
# 3        Because of the cloudy weather, one of the  grandfathers           m
# 4        Because of the cloudy weather, one of the      monarchs           n
# 5        Because of the cloudy weather, one of the        queens           f
# ...                                            ...           ...         ...
# 626             After such a long day, most of the     daughters           f
# 627             After such a long day, most of the          sons           m
# 628             After such a long day, most of the       spouses           n
# 629             After such a long day, most of the         wives           f
# 630             After such a long day, most of the      husbands           m
#
#                                                phrases_cut  \
# item_no
# 1        The grandparents were waiting on a bench. Beca...
# 2        The grandmothers were waiting on a bench. Beca...
# 3        The grandfathers were waiting on a bench. Beca...
# 4        The monarchs were waiting on a bench. Because ...
# 5        The queens were waiting on a bench. Because of...
# ...                                                    ...
# 626      The daughters were getting off the plane. Afte...
# 627      The sons were getting off the plane. After suc...
# 628      The spouses were getting off the plane. After ...
# 629      The wives were getting off the plane. After su...
# 630      The husbands were getting off the plane. After...
#
#                                    next_5
# item_no
# 1                  grandparents said, "It
# 2                      grandmothers said,
# 3                      grandfathers said,
# 4                  monarchs was not happy
# 5                queens was wearing a hat
# ...                                   ...
# 626       passengers were tired and ready
# 627        passengers were tired and just
# 628         passengers were just happy to
# 629             wives were tired and just
# 630              husbands were tired. The
#
# [630 rows x 6 columns]

# %% [markdown]
# ## Collect Annotator Data

# %%
# get annotator data
ann_1 = pd.read_csv(os.path.join(annotations_dir,'annotator_1.csv'), index_col=0)
ann_2 = pd.read_csv(os.path.join(annotations_dir,'annotator_2.csv'), index_col=0)
ann_3 = pd.read_csv(os.path.join(annotations_dir,'annotator_3.csv'), index_col=0)

# shorten column names
ann_1.rename(columns={'mentioned gender':'gender_a1', 'refers back?':'ref_a1'}, inplace=True)
ann_2.rename(columns={'mentioned gender':'gender_a2', 'refers back?':'ref_a2'}, inplace=True)
ann_3.rename(columns={'mentioned gender':'gender_a3', 'refers back?':'ref_a3'}, inplace=True)

# add two new coplumns to the data frame
annotations = pd.concat([og_df.iloc[:,2:4],
                         ann_1, 
                         ann_2.loc[:,'gender_a2':'ref_a2'],
                         ann_3.loc[:,'gender_a3':'ref_a3']], axis=1)

# %%
annotations.head()
# Out:
#             ante_noun ante_gender  \
# item_no
# 1        grandparents           n
# 2        grandmothers           f
# 3        grandfathers           m
# 4            monarchs           n
# 5              queens           f
#
#                                                  sentences  \
# item_no
# 1        The grandparents were waiting on a bench. Beca...
# 2        The grandmothers were waiting on a bench. Beca...
# 3        The grandfathers were waiting on a bench. Beca...
# 4        The monarchs were waiting on a bench. Because ...
# 5        The queens were waiting on a bench. Because of...
#
#                      continuation gender_a1 ref_a1 gender_a2 ref_a2 gender_a3  \
# item_no
# 1          grandparents said, "It         n    yes         n    yes         n
# 2              grandmothers said,         f    yes         f    yes         f
# 3              grandfathers said,         m    yes         m    yes         m
# 4          monarchs was not happy         n    yes         n    yes         n
# 5        queens was wearing a hat         f    yes         f    yes         f
#
#         ref_a3
# item_no
# 1          yes
# 2          yes
# 3          yes
# 4          yes
# 5          yes

# %% [markdown]
# ## Majority Voting

# %%
def majority_vote(lst):
    """Function to get the majority vote of a list of 3 elements"""
    # count elements
    c = Counter(lst)
    # with three elements, majority is 2
    if c.most_common(1)[0][1] >= 2:
        return c.most_common(1)[0][0]
    # if there is no majority, return nan
    else:
        return np.nan

# %%
# collect majority votes
mv_gender = []
mv_ref = []
for index, row in annotations.iterrows():
    mv_gender.append(majority_vote([row[4], row[6], row[8]]))
    mv_ref.append(majority_vote([row[5], row[7], row[9]]))
# Out:
# /tmp/ipykernel_104256/3198474368.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mv_gender.append(majority_vote([row[4], row[6], row[8]]))
# /tmp/ipykernel_104256/3198474368.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mv_ref.append(majority_vote([row[5], row[7], row[9]]))

# %%
# add majority votes to the data frame
annotations['gender_mv'] = mv_gender
annotations['ref_mv'] = mv_ref

# %%
annotations
# Out:
#             ante_noun ante_gender  \
# item_no
# 1        grandparents           n
# 2        grandmothers           f
# 3        grandfathers           m
# 4            monarchs           n
# 5              queens           f
# ...               ...         ...
# 626         daughters           f
# 627              sons           m
# 628           spouses           n
# 629             wives           f
# 630          husbands           m
#
#                                                  sentences  \
# item_no
# 1        The grandparents were waiting on a bench. Beca...
# 2        The grandmothers were waiting on a bench. Beca...
# 3        The grandfathers were waiting on a bench. Beca...
# 4        The monarchs were waiting on a bench. Because ...
# 5        The queens were waiting on a bench. Because of...
# ...                                                    ...
# 626      The daughters were getting off the plane. Afte...
# 627      The sons were getting off the plane. After suc...
# 628      The spouses were getting off the plane. After ...
# 629      The wives were getting off the plane. After su...
# 630      The husbands were getting off the plane. After...
#
#                             continuation gender_a1 ref_a1 gender_a2 ref_a2  \
# item_no
# 1                 grandparents said, "It         n    yes         n    yes
# 2                     grandmothers said,         f    yes         f    yes
# 3                     grandfathers said,         m    yes         m    yes
# 4                 monarchs was not happy         n    yes         n    yes
# 5               queens was wearing a hat         f    yes         f    yes
# ...                                  ...       ...    ...       ...    ...
# 626      passengers were tired and ready         f     no         n     no
# 627       passengers were tired and just         m     no         n     no
# 628        passengers were just happy to         n     no         n     no
# 629            wives were tired and just         f    yes         f    yes
# 630             husbands were tired. The         m    yes         m    yes
#
#         gender_a3 ref_a3 gender_mv ref_mv
# item_no
# 1               n    yes         n    yes
# 2               f    yes         f    yes
# 3               m    yes         m    yes
# 4               n    yes         n    yes
# 5               f    yes         f    yes
# ...           ...    ...       ...    ...
# 626             n     no         n     no
# 627             n     no         n     no
# 628             n     no         n     no
# 629             f    yes         f    yes
# 630             m    yes         m    yes
#
# [630 rows x 12 columns]

# %% [markdown]
# ## Save Data

# %%
# save the annotations
annotations.to_csv(os.path.join(annotations_dir, 'annotations_EN_majorityvotes.csv'),
                   na_rep='NULL')

# %% [markdown]
# ## Data Exploration

# %%
# show all rows where three annotators disagreed in gender

# %%
filtered_ann_gender = annotations[
    (annotations['gender_a1'] != annotations['gender_a2']) &
    (annotations['gender_a2'] != annotations['gender_a3'])
]

# %%
len(filtered_ann_gender)
# Out:
# 32

# %%
filtered_ann_ref = annotations[
    (annotations['ref_a1'] != annotations['ref_a2']) &
    (annotations['ref_a2'] != annotations['ref_a3'])
]
len(filtered_ann_ref)
# Out:
# 86

# %%
print(annotations['gender_mv'].value_counts(dropna=False),
      annotations['ref_mv'].value_counts(dropna=False))
# Out:
# gender_mv
# n      289
# m      160
# f      159
# NaN     22
# Name: count, dtype: int64 ref_mv
# yes    396
# no     226
# NaN      8
# Name: count, dtype: int64
